# %% [markdown]
# # 导入工具包

# %%
import networkx as nx
# 数据可视化
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['font.sans-serif'] = ['SimHei'] # 设置中文字体为黑体
plt.rcParams['axes.unicode_minus'] = False # 解决负号'-'显示为方块的问题

# %% [markdown]
# # 经典图结构

# %%
# 全连接无向图
G=nx.complete_graph(5)
nx.draw(G)
# 全图连接数
print(G.size())
# Out:
# 10

# %%
# 全连接有向图
G=nx.complete_graph(5, create_using=nx.DiGraph())
nx.draw(G)
print(G.is_directed())
# Out:
# True

# %%
# 环状图
G=nx.cycle_graph(6)
nx.draw(G)

# %%
# 梯度图
G=nx.ladder_graph(5)
nx.draw(G)

# %%
# 线性串珠图
G=nx.path_graph(6)
nx.draw(G)

# %%
# 星状图
G=nx.star_graph(5)
nx.draw(G)

# %%
# 轮辐图
G=nx.wheel_graph(6)
nx.draw(G)

# %%
# 二项树
G=nx.binomial_tree(5)
nx.draw(G)

# %%
# 栅格图
G1=nx.grid_2d_graph(3,5)
nx.draw(G1)

# %%
G2=nx.grid_graph(dim=[2,3,4])
nx.draw(G2)

# %%
G3=nx.triangular_lattice_graph(2,5)
nx.draw(G3)

# %%
G4=nx.hexagonal_lattice_graph(2,3)
nx.draw(G4)

# %%
G5=nx.hypercube_graph(4)
nx.draw(G5)

# %% [markdown]
# # 内置图结构

# %% [markdown]
# ## 无向图

# %%
# 钻石图
G=nx.diamond_graph()
nx.draw(G)

# %%
# 牛角图
G=nx.bull_graph()
nx.draw(G)

# %%
# frucht图
G=nx.frucht_graph() 
nx.draw(G)

# %%
# 房屋图
G=nx.house_graph()
nx.draw(G)

# %%
# house_x图
G=nx.house_x_graph()
nx.draw(G)

# %%
# Petersen图
G=nx.petersen_graph()
nx.draw(G)

# %%
# 风筝图
G=nx.krackhardt_kite_graph()
nx.draw(G)

# %%
# 随机图
G=nx.erdos_renyi_graph(10,0.3)
nx.draw(G)

# %% [markdown]
# ## 有向图

# %%
# 无标度有向图
G=nx.scale_free_graph(10) # 有概率产生多重边和自环
nx.draw(G)

# %% [markdown]
# ## 其他常用图

# %%
# 社交网络
G=nx.karate_club_graph() # 空手道俱乐部社交网络
nx.draw(G,with_labels=True)

# %%
# 查看节点类别
print(G.nodes[20]['club'])
print(G.nodes[21]['club'])
# Out:
# Officer
# Mr. Hi

# %%
# 雨果悲惨世界人物关系图
G=nx.les_miserables_graph()
plt.figure(figsize=(12,10))
pos=nx.spring_layout(G,seed=10) # 设置布局
nx.draw(G,pos,with_labels=True)

# %%
# 家庭谱系图
G=nx.florentine_families_graph()
nx.draw(G,with_labels=True)

# %%
# 社群聚类图
G=nx.caveman_graph(4,3)
nx.draw(G,with_labels=True)

# %% [markdown]
# # 树结构

# %%
tree=nx.random_labeled_tree(n=10,seed=0)
nx.write_network_text(tree, sources=[0])
# Out:
# ╙── 0
#     ├── 3
#     └── 4
#         ├── 6
#         │   ├── 1
#         │   ├── 2
#         │   └── 7
#         │       └── 8
#         │           └── 5
#         └── 9
